# %%
from utils import *

# %% [markdown]
# Lets see what our options for the DTS files we have in our data directory

# %%
# update the file paths to the parquet files for Silixa and FibrisTerre data based on your operation system and directory structure
FILE_PATH_Silixa="/Volumes/staff-umbrella/DAPWELLFO/DTS/Silixa/parquet"
FILE_PATH_Fibris="/Volumes/staff-umbrella/DAPWELLFO/DTS/FibrisTerre/parquet"

# %% [markdown]
# Here are the options for the Silixa interrogator

# %%
print("Options for Silixa", list_options(FILE_PATH_Silixa))
print("Options for FibrisTerre", list_options(FILE_PATH_Fibris))
# Out:
# Options for Silixa {'DELGT02S2': ['SE', 'DE'], 'DELGT01': ['SE']}
# Options for FibrisTerre {'DELGT01': ['SE'], 'DELGT02S2': ['SE']}

# %% [markdown]
# From the output we can see the DELGT02S2 well has both single and double ended and the DELGT01 has only single ended fibre optic measurements for the Silixa interrogator.
#
# For the FibrisTerre interrogator we have only single ended measurements from the both wellborn.

# %% [markdown]
# !!!! NOTE:
#
# if you are running this notebook in vscode, you can ignore the following cell. It is only for jupyter notebook users to load require.js for pyecharts visualisations.

# %%
from IPython.display import HTML
HTML("""<script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>""")
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>

# %% [markdown]
# ### Calendar plot to see the measurement frequencies

# %%
#Silixa DELGT01
plot_calendar(
    data=aggregate_date_occurrences(list_dates(FILE_PATH_Silixa, "DELGT01", "SE")),
    title="DELGT01 Multi Mode Single Ended DTS Measurements",
    upper_range=10
    )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d66ec60174b642fbb48f363be2c83adb" style="width:900px; height:480px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d66ec60174b642fbb48f363be2c83adb = echarts.init(
#                     document.getElementById('d66ec60174b642fbb48f363be2c83adb'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_d66ec60174b642fbb48f363be2c83adb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "2025",
#             "data": [],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         },
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "calendarIndex": 1,
#             "name": "2026",
#             "data": [
#                 [
#                     "2026-01-20",
#                     4
#                 ],
#                 [
#                     "2026-01-21",
#                     6
#                 ],
#                 [
#                     "2026-01-22",
#                     6
#                 ],
#                 [
#                     "2026-01-23",
#                     6
#                 ],
#                 [
#                     "2026-01-24",
#                     6
#                 ],
#                 [
#                     "2026-01-25",
#                     6
#                 ],
#                 [
#                     "2026-01-26",
#                     6
#                 ],
#                 [
#                     "2026-01-27",
#                     6
#                 ],
#                 [
#                     "2026-01-28",
#                     3
#                 ],
#                 [
#                     "2026-02-02",
#                     1
#                 ],
#                 [
#                     "2026-02-06",
#                     10
#                 ],
#                 [
#                     "2026-02-07",
#                     24
#                 ],
#                 [
#                     "2026-02-08",
#                     24
#                 ],
#                 [
#                     "2026-02-09",
#                     24
#                 ],
#                 [
#                     "2026-02-10",
#                     24
#                 ],
#                 [
#                     "2026-02-11",
#                     24
#                 ],
#                 [
#                     "2026-02-12",
#                     12
#                 ],
#                 [
#                     "2026-02-13",
#                     17
#                 ],
#                 [
#                     "2026-02-14",
#                     24
#                 ],
#                 [
#                     "2026-02-15",
#                     16
#                 ],
#                 [
#                     "2026-02-16",
#                     12
#                 ],
#                 [
#                     "2026-02-17",
#                     24
#                 ],
#                 [
#                     "2026-02-18",
#                     24
#                 ],
#                 [
#                     "2026-02-19",
#                     24
#                 ],
#                 [
#                     "2026-02-20",
#                     24
#                 ],
#                 [
#                     "2026-02-21",
#                     24
#                 ],
#                 [
#                     "2026-02-22",
#                     24
#                 ],
#                 [
#                     "2026-02-23",
#                     171
#                 ],
#                 [
#                     "2026-02-24",
#                     287
#                 ],
#                 [
#                     "2026-02-25",
#                     275
#                 ],
#                 [
#                     "2026-02-26",
#                     288
#                 ],
#                 [
#                     "2026-02-27",
#                     99
#                 ],
#                 [
#                     "2026-02-28",
#                     24
#                 ],
#                 [
#                     "2026-03-01",
#                     24
#                 ],
#                 [
#                     "2026-03-02",
#                     24
#                 ],
#                 [
#                     "2026-03-03",
#                     24
#                 ],
#                 [
#                     "2026-03-04",
#                     24
#                 ],
#                 [
#                     "2026-03-05",
#                     24
#                 ],
#                 [
#                     "2026-03-06",
#                     24
#                 ],
#                 [
#                     "2026-03-07",
#                     24
#                 ],
#                 [
#                     "2026-03-08",
#                     24
#                 ],
#                 [
#                     "2026-03-09",
#                     24
#                 ],
#                 [
#                     "2026-03-10",
#                     24
#                 ],
#                 [
#                     "2026-03-11",
#                     24
#                 ],
#                 [
#                     "2026-03-12",
#                     24
#                 ],
#                 [
#                     "2026-03-13",
#                     24
#                 ],
#                 [
#                     "2026-03-14",
#                     24
#                 ],
#                 [
#                     "2026-03-15",
#                     24
#                 ],
#                 [
#                     "2026-03-16",
#                     12
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2025",
#                 "2026"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "triggerEvent": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "displayTransition": true,
#         "textStyle": {
#             "fontSize": 14,
#             "richInheritPlainLabel": true
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "calendar": [
#         {
#             "zlevel": 0,
#             "z": 2,
#             "left": "60",
#             "top": "50",
#             "right": "60",
#             "width": "auto",
#             "orient": "horizontal",

# %%
#Fibris DELGT01
plot_calendar(
    data=aggregate_date_occurrences(list_dates(FILE_PATH_Fibris, "DELGT01", "SE")),
    title="DELGT01 Single Mode Single Ended DTS Measurements",
    upper_range=10
    )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b10288718f864a3aa67edd2976e0f97d" style="width:900px; height:480px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b10288718f864a3aa67edd2976e0f97d = echarts.init(
#                     document.getElementById('b10288718f864a3aa67edd2976e0f97d'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_b10288718f864a3aa67edd2976e0f97d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "2025",
#             "data": [],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         },
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "calendarIndex": 1,
#             "name": "2026",
#             "data": [
#                 [
#                     "2026-01-21",
#                     4
#                 ],
#                 [
#                     "2026-01-22",
#                     9
#                 ],
#                 [
#                     "2026-01-23",
#                     9
#                 ],
#                 [
#                     "2026-01-24",
#                     9
#                 ],
#                 [
#                     "2026-01-25",
#                     9
#                 ],
#                 [
#                     "2026-01-26",
#                     9
#                 ],
#                 [
#                     "2026-01-27",
#                     9
#                 ],
#                 [
#                     "2026-01-28",
#                     3
#                 ],
#                 [
#                     "2026-02-05",
#                     7
#                 ],
#                 [
#                     "2026-02-06",
#                     12
#                 ],
#                 [
#                     "2026-02-07",
#                     10
#                 ],
#                 [
#                     "2026-02-08",
#                     9
#                 ],
#                 [
#                     "2026-02-09",
#                     9
#                 ],
#                 [
#                     "2026-02-10",
#                     9
#                 ],
#                 [
#                     "2026-02-11",
#                     8
#                 ],
#                 [
#                     "2026-02-12",
#                     2
#                 ],
#                 [
#                     "2026-02-19",
#                     6
#                 ],
#                 [
#                     "2026-02-20",
#                     12
#                 ],
#                 [
#                     "2026-02-21",
#                     10
#                 ],
#                 [
#                     "2026-02-22",
#                     9
#                 ],
#                 [
#                     "2026-02-23",
#                     10
#                 ],
#                 [
#                     "2026-02-24",
#                     13
#                 ],
#                 [
#                     "2026-02-25",
#                     12
#                 ],
#                 [
#                     "2026-02-26",
#                     12
#                 ],
#                 [
#                     "2026-02-27",
#                     12
#                 ],
#                 [
#                     "2026-02-28",
#                     12
#                 ],
#                 [
#                     "2026-03-01",
#                     12
#                 ],
#                 [
#                     "2026-03-02",
#                     12
#                 ],
#                 [
#                     "2026-03-03",
#                     12
#                 ],
#                 [
#                     "2026-03-04",
#                     12
#                 ],
#                 [
#                     "2026-03-05",
#                     12
#                 ],
#                 [
#                     "2026-03-06",
#                     12
#                 ],
#                 [
#                     "2026-03-07",
#                     12
#                 ],
#                 [
#                     "2026-03-08",
#                     12
#                 ],
#                 [
#                     "2026-03-09",
#                     12
#                 ],
#                 [
#                     "2026-03-10",
#                     12
#                 ],
#                 [
#                     "2026-03-11",
#                     12
#                 ],
#                 [
#                     "2026-03-12",
#                     11
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2025",
#                 "2026"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "triggerEvent": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "displayTransition": true,
#         "textStyle": {
#             "fontSize": 14,
#             "richInheritPlainLabel": true
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "calendar": [
#         {
#             "zlevel": 0,
#             "z": 2,
#             "left": "60",
#             "top": "50",
#             "right": "60",
#             "width": "auto",
#             "orient": "horizontal",
#             "range": "2025",
#             "cellSize": 20,
#             "dayLabel": {
#                 "show": true,
#                 "firstDay": 0,
#                 "position": "start",
#                 "nameMap": [
#                     "Mon",
#                     "Tue",
#                     "Wed",
#                     "Thu",
#                     "Fri",
#                     "Sat",
#                     "Sun"
#                 ],
#                 "color": "#000",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 12
#             },
#             "monthLabel": {
#                 "show": true,
#                 "position": "start",
#                 "nameMap": [
#                     "Jan",
#                     "Feb",
#                     "Mar",
#                     "Apr",
#                     "May",
#                     "Jun",
#                     "Jul",
#                     "Aug",
#                     "Sep",
#                     "Oct",
#                     "Nov",

# %%
#Silixa DELGT02 Single Ended
plot_calendar(
    data=aggregate_date_occurrences(list_dates(FILE_PATH_Silixa, "DELGT02S2", "SE")),
    title="DELGT02 Multi Mode Single Ended DTS Measurements",
    upper_range=50
    )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1fa492ac516c41669063118218fb69cc" style="width:900px; height:480px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1fa492ac516c41669063118218fb69cc = echarts.init(
#                     document.getElementById('1fa492ac516c41669063118218fb69cc'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_1fa492ac516c41669063118218fb69cc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "2025",
#             "data": [],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         },
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "calendarIndex": 1,
#             "name": "2026",
#             "data": [
#                 [
#                     "2026-01-06",
#                     4
#                 ],
#                 [
#                     "2026-01-07",
#                     8
#                 ],
#                 [
#                     "2026-01-08",
#                     8
#                 ],
#                 [
#                     "2026-01-09",
#                     8
#                 ],
#                 [
#                     "2026-01-10",
#                     8
#                 ],
#                 [
#                     "2026-01-11",
#                     8
#                 ],
#                 [
#                     "2026-01-12",
#                     8
#                 ],
#                 [
#                     "2026-01-13",
#                     8
#                 ],
#                 [
#                     "2026-01-14",
#                     8
#                 ],
#                 [
#                     "2026-01-15",
#                     8
#                 ],
#                 [
#                     "2026-01-16",
#                     8
#                 ],
#                 [
#                     "2026-01-17",
#                     8
#                 ],
#                 [
#                     "2026-01-18",
#                     8
#                 ],
#                 [
#                     "2026-01-19",
#                     8
#                 ],
#                 [
#                     "2026-01-20",
#                     8
#                 ],
#                 [
#                     "2026-01-21",
#                     6
#                 ],
#                 [
#                     "2026-01-22",
#                     6
#                 ],
#                 [
#                     "2026-01-23",
#                     6
#                 ],
#                 [
#                     "2026-01-24",
#                     6
#                 ],
#                 [
#                     "2026-01-25",
#                     6
#                 ],
#                 [
#                     "2026-01-26",
#                     6
#                 ],
#                 [
#                     "2026-01-27",
#                     6
#                 ],
#                 [
#                     "2026-01-28",
#                     3
#                 ],
#                 [
#                     "2026-02-02",
#                     1
#                 ],
#                 [
#                     "2026-02-06",
#                     10
#                 ],
#                 [
#                     "2026-02-07",
#                     24
#                 ],
#                 [
#                     "2026-02-08",
#                     24
#                 ],
#                 [
#                     "2026-02-09",
#                     24
#                 ],
#                 [
#                     "2026-02-10",
#                     24
#                 ],
#                 [
#                     "2026-02-11",
#                     24
#                 ],
#                 [
#                     "2026-02-12",
#                     13
#                 ],
#                 [
#                     "2026-02-13",
#                     17
#                 ],
#                 [
#                     "2026-02-14",
#                     24
#                 ],
#                 [
#                     "2026-02-15",
#                     16
#                 ],
#                 [
#                     "2026-02-16",
#                     12
#                 ],
#                 [
#                     "2026-02-17",
#                     24
#                 ],
#                 [
#                     "2026-02-18",
#                     24
#                 ],
#                 [
#                     "2026-02-19",
#                     24
#                 ],
#                 [
#                     "2026-02-20",
#                     24
#                 ],
#                 [
#                     "2026-02-21",
#                     24
#                 ],
#                 [
#                     "2026-02-22",
#                     24
#                 ],
#                 [
#                     "2026-02-23",
#                     171
#                 ],
#                 [
#                     "2026-02-24",
#                     288
#                 ],
#                 [
#                     "2026-02-25",
#                     275
#                 ],
#                 [
#                     "2026-02-26",
#                     287
#                 ],
#                 [
#                     "2026-02-27",
#                     99
#                 ],
#                 [
#                     "2026-02-28",
#                     24
#                 ],
#                 [
#                     "2026-03-01",
#                     24
#                 ],
#                 [
#                     "2026-03-02",
#                     24
#                 ],
#                 [
#                     "2026-03-03",
#                     24
#                 ],
#                 [
#                     "2026-03-04",
#                     24
#                 ],
#                 [
#                     "2026-03-05",
#                     24
#                 ],
#                 [
#                     "2026-03-06",
#                     24
#                 ],
#                 [
#                     "2026-03-07",
#                     24
#                 ],
#                 [
#                     "2026-03-08",
#                     24
#                 ],
#                 [
#                     "2026-03-09",
#                     24
#                 ],
#                 [
#                     "2026-03-10",
#                     24
#                 ],
#                 [
#                     "2026-03-11",
#                     24
#                 ],
#                 [
#                     "2026-03-12",
#                     24
#                 ],
#                 [
#                     "2026-03-13",
#                     24
#                 ],
#                 [
#                     "2026-03-14",
#                     24
#                 ],
#                 [
#                     "2026-03-15",
#                     24
#                 ],
#                 [
#                     "2026-03-16",
#                     13
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2025",
#                 "2026"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap":

# %%
#FibrisTerre DELGT02 Single Ended
plot_calendar(
    data=aggregate_date_occurrences(list_dates(FILE_PATH_Fibris, "DELGT02S2", "SE")),
    title="DELGT02 Single Mode Single Ended DTS Measurements",
    upper_range=10
    )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2b0a6f82e58843bb983c70f2c1bd959a" style="width:900px; height:480px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2b0a6f82e58843bb983c70f2c1bd959a = echarts.init(
#                     document.getElementById('2b0a6f82e58843bb983c70f2c1bd959a'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_2b0a6f82e58843bb983c70f2c1bd959a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "2025",
#             "data": [],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         },
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "calendarIndex": 1,
#             "name": "2026",
#             "data": [
#                 [
#                     "2026-01-21",
#                     4
#                 ],
#                 [
#                     "2026-01-22",
#                     9
#                 ],
#                 [
#                     "2026-01-23",
#                     9
#                 ],
#                 [
#                     "2026-01-24",
#                     9
#                 ],
#                 [
#                     "2026-01-25",
#                     9
#                 ],
#                 [
#                     "2026-01-26",
#                     9
#                 ],
#                 [
#                     "2026-01-27",
#                     9
#                 ],
#                 [
#                     "2026-01-28",
#                     3
#                 ],
#                 [
#                     "2026-02-05",
#                     7
#                 ],
#                 [
#                     "2026-02-06",
#                     12
#                 ],
#                 [
#                     "2026-02-07",
#                     10
#                 ],
#                 [
#                     "2026-02-08",
#                     10
#                 ],
#                 [
#                     "2026-02-09",
#                     9
#                 ],
#                 [
#                     "2026-02-10",
#                     9
#                 ],
#                 [
#                     "2026-02-11",
#                     7
#                 ],
#                 [
#                     "2026-02-12",
#                     3
#                 ],
#                 [
#                     "2026-02-19",
#                     6
#                 ],
#                 [
#                     "2026-02-20",
#                     12
#                 ],
#                 [
#                     "2026-02-21",
#                     11
#                 ],
#                 [
#                     "2026-02-22",
#                     9
#                 ],
#                 [
#                     "2026-02-23",
#                     10
#                 ],
#                 [
#                     "2026-02-24",
#                     13
#                 ],
#                 [
#                     "2026-02-25",
#                     12
#                 ],
#                 [
#                     "2026-02-26",
#                     12
#                 ],
#                 [
#                     "2026-02-27",
#                     12
#                 ],
#                 [
#                     "2026-02-28",
#                     12
#                 ],
#                 [
#                     "2026-03-01",
#                     12
#                 ],
#                 [
#                     "2026-03-02",
#                     12
#                 ],
#                 [
#                     "2026-03-03",
#                     12
#                 ],
#                 [
#                     "2026-03-04",
#                     12
#                 ],
#                 [
#                     "2026-03-05",
#                     12
#                 ],
#                 [
#                     "2026-03-06",
#                     12
#                 ],
#                 [
#                     "2026-03-07",
#                     12
#                 ],
#                 [
#                     "2026-03-08",
#                     12
#                 ],
#                 [
#                     "2026-03-09",
#                     12
#                 ],
#                 [
#                     "2026-03-10",
#                     12
#                 ],
#                 [
#                     "2026-03-11",
#                     12
#                 ],
#                 [
#                     "2026-03-12",
#                     11
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2025",
#                 "2026"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "triggerEvent": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "displayTransition": true,
#         "textStyle": {
#             "fontSize": 14,
#             "richInheritPlainLabel": true
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "calendar": [
#         {
#             "zlevel": 0,
#             "z": 2,
#             "left": "60",
#             "top": "50",
#             "right": "60",
#             "width": "auto",
#             "orient": "horizontal",
#             "range": "2025",
#             "cellSize": 20,
#             "dayLabel": {
#                 "show": true,
#                 "firstDay": 0,
#                 "position": "start",
#                 "nameMap": [
#                     "Mon",
#                     "Tue",
#                     "Wed",
#                     "Thu",
#                     "Fri",
#                     "Sat",
#                     "Sun"
#                 ],
#                 "color": "#000",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 12
#             },
#             "monthLabel": {
#                 "show": true,
#                 "position": "start",
#                 "nameMap": [
#                     "Jan",
#                     "Feb",
#                     "Mar",
#                     "Apr",
#                     "May",
#                     "Jun",
#                     "Jul",
#                     "Aug",
#                     "Sep",
#                     "Oct",
#                     "Nov",

# %%
#Silixa DELGT02 Double Ended
plot_calendar(
    data=aggregate_date_occurrences(list_dates(FILE_PATH_Silixa, "DELGT02S2", "DE")),
    title="DELGT02 MultiMode Double Ended DTS Measurements",
    upper_range=10
    )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="73e768fd5a744beb990ed9ce35a5147a" style="width:900px; height:480px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_73e768fd5a744beb990ed9ce35a5147a = echarts.init(
#                     document.getElementById('73e768fd5a744beb990ed9ce35a5147a'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_73e768fd5a744beb990ed9ce35a5147a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "2025",
#             "data": [
#                 [
#                     "2025-12-11",
#                     2
#                 ],
#                 [
#                     "2025-12-12",
#                     4
#                 ],
#                 [
#                     "2025-12-13",
#                     4
#                 ],
#                 [
#                     "2025-12-14",
#                     4
#                 ],
#                 [
#                     "2025-12-15",
#                     5
#                 ],
#                 [
#                     "2025-12-16",
#                     4
#                 ],
#                 [
#                     "2025-12-17",
#                     4
#                 ],
#                 [
#                     "2025-12-18",
#                     4
#                 ],
#                 [
#                     "2025-12-19",
#                     4
#                 ],
#                 [
#                     "2025-12-20",
#                     4
#                 ],
#                 [
#                     "2025-12-21",
#                     4
#                 ],
#                 [
#                     "2025-12-22",
#                     4
#                 ],
#                 [
#                     "2025-12-23",
#                     4
#                 ],
#                 [
#                     "2025-12-24",
#                     4
#                 ],
#                 [
#                     "2025-12-25",
#                     4
#                 ],
#                 [
#                     "2025-12-26",
#                     4
#                 ],
#                 [
#                     "2025-12-27",
#                     4
#                 ],
#                 [
#                     "2025-12-28",
#                     4
#                 ],
#                 [
#                     "2025-12-29",
#                     4
#                 ],
#                 [
#                     "2025-12-30",
#                     4
#                 ],
#                 [
#                     "2025-12-31",
#                     4
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         },
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "calendarIndex": 1,
#             "name": "2026",
#             "data": [
#                 [
#                     "2026-01-01",
#                     4
#                 ],
#                 [
#                     "2026-01-02",
#                     4
#                 ],
#                 [
#                     "2026-01-03",
#                     4
#                 ],
#                 [
#                     "2026-01-04",
#                     4
#                 ],
#                 [
#                     "2026-01-05",
#                     4
#                 ],
#                 [
#                     "2026-01-06",
#                     2
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "inside",
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2025",
#                 "2026"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "triggerEvent": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "displayTransition": true,
#         "textStyle": {
#             "fontSize": 14,
#             "richInheritPlainLabel": true
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "calendar": [
#         {
#             "zlevel": 0,
#             "z": 2,
#             "left": "60",
#             "top": "50",
#             "right": "60",
#             "width": "auto",
#             "orient": "horizontal",
#             "range": "2025",
#             "cellSize": 20,
#             "dayLabel": {
#                 "show": true,
#                 "firstDay": 0,
#                 "position": "start",
#                 "nameMap": [
#                     "Mon",
#                     "Tue",
#                     "Wed",
#                     "Thu",
#                     "Fri",
#                     "Sat",
#                     "Sun"
#                 ],
#                 "color": "#000",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 12
#             },
#             "monthLabel": {
#                 "show": true,
#                 "position": "start",
#                 "nameMap": [
#                     "Jan",
#                     "Feb",
#                     "Mar",
#                     "Apr",
#                     "May",
#                     "Jun",
#                     "Jul",
#                     "Aug",
#                     "Sep",
#                     "Oct",
#                     "Nov",
#                     "Dec"
#                 ],
#                 "color": "#000",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 12
#             },
#             "yearLabel": {
#                 "show": true,
#                 "margin": 40,
#                 "color": "#000",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 12
#             },
#             "silent": false
#         },
#         {
#             "zlevel": 0,
#             "z": 2,
#             "left": "60",
#             "top": "250",
#             "right": "60",
#             "width": "auto",
#             "orient": "horizontal",
#             "range": "2026",
#             "cellSize": 20,
#             "dayLabel": {
#                 "show": true,
#                 "firstDay": 0,
#                 "position": "start",
#                 "nameMap": [
#                     "Mon",
#                     "Tue",

# %% [markdown]
# ### Plotting heatmaps

# %%
#Silixa DELGT01 Single Ended
plot_heatmap(
    dataframe=bin_dataframe(
        dataframe=load_dts_data(
            list_files(data_path=FILE_PATH_Silixa, wellname="DELGT01", end_type="SE")
        ),
        bin_size=5,
    ),
    title="DELGT01 Multi Mode Single Ended DTS Measurements",
    well_top=145
)

# %%
#FibrisTerre DELGT01 Single Ended
plot_heatmap(
    dataframe=bin_dataframe(
        dataframe=load_dts_data(
            list_files(data_path=FILE_PATH_Fibris, wellname="DELGT01", end_type="SE")
        ),
        bin_size=5,
    ),
    title="DELGT01 Single Mode Single Ended DTS Measurements",
    well_top=145
)

# %%
#Silixa DELGT02S2 Single Ended
plot_heatmap(
    dataframe=bin_dataframe(
        dataframe=load_dts_data(
            list_files(data_path=FILE_PATH_Silixa, wellname="DELGT02S2", end_type="SE")
        ),
        bin_size=5,
    ),
    title="DELGT02S2 Multi Mode Single Ended DTS Measurements",
    well_top=232
)

# %%
#FibrisTerre DELGT02S2 Single Ended
plot_heatmap(
    dataframe=bin_dataframe(
        dataframe=load_dts_data(
            list_files(data_path=FILE_PATH_Fibris, wellname="DELGT02S2", end_type="SE")
        ),
        bin_size=5,
    ),
    title="DELGT02S2 Single Mode Single Ended DTS Measurements",
    well_top=232
)

# %%
#Silixa DELGT02S2 Double Ended
plot_heatmap(
    dataframe=bin_dataframe(
        dataframe=load_dts_data(
            list_files(data_path=FILE_PATH_Silixa, wellname="DELGT02S2", end_type="DE")
        ),
        bin_size=5,
    ),
    title="DELGT02S2 Double Mode Double Ended DTS Measurements",
    well_top=232
)
